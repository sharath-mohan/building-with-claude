# %% [markdown]
# temperature of 0 makes the output deterministic
# lower temperature decreases the creative, higher makes it creative

# %%
from dotenv import load_dotenv

from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-0"


def chat(
    prompt,
    temperature=1.0,
    system=None,
):
    params = {
        "model": model,
        "max_tokens": 100,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": temperature,
    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    print(message.content[0].text)

# %%
chat("generate a one sentence movie idea", temperature=0.0)
# Out:
# A time-traveling janitor discovers that every mess he cleans up in the present prevents a catastrophic disaster in the future, but he only has 24 hours to clean the entire city before humanity's timeline collapses forever.

# %% [markdown]
# most commonloy we see this time traveller

# %%
chat("generate a one sentence movie idea", temperature=1.0)
# Out:
# A lonely lighthouse keeper discovers that the beam of light from his lighthouse can transport him 24 hours into the past, but each time he uses it, someone he loves disappears from his present timeline forever.
